# %%
import numpy as np
import pandas as pd
import pickle

# %%
products_df = pd.read_csv("data\data_processed_gte25\products.csv")
products_df.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 2          34                            Peanut Butter Cereal       121
# 3          45                               European Cucumber        83
# 4          79                Wild Albacore Tuna No Salt Added        95
#
#    department_id                          aisle    department
# 0             19                  cookies cakes        snacks
# 1              7  water seltzer sparkling water     beverages
# 2             14                         cereal     breakfast
# 3              4               fresh vegetables       produce
# 4             15            canned meat seafood  canned goods

# %%
orders_df = pd.read_csv("data\data_processed_gte25\orders.csv")
orders_df.head()
# Out:
#    order_id  product_list  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2         33120                  1          5                  9
# 1         2         17794                  2          5                  9
# 2         2          9327                  4          5                  9
# 3         3         17668                  1          5                 17
# 4         3         24838                  2          5                 17
#
#    length
# 0       3
# 1       3
# 2       3
# 3       5
# 4       5

# %%
print("Shape of orders dataframe: ", orders_df.shape)
print("Shape of productss dataframe: ", products_df.shape)
# Out:
# Shape of orders dataframe:  (323705, 6)
# Shape of productss dataframe:  (2965, 6)

# %%
products_df["product_id"]
# Out:
# 0           1
# 1          10
# 2          34
# 3          45
# 4          79
#         ...
# 2960    49605
# 2961    49610
# 2962    49621
# 2963    49667
# 2964    49683
# Name: product_id, Length: 2965, dtype: int64

# %%
products_df["aisle_id"].max()
# Out:
# 134

# %%
products_df["department_id"].min()
# Out:
# 1

# %%
products_df["department_id"].nunique()
# Out:
# 21

# %%
orders_df["product_list"]
# Out:
# 0         33120
# 1         17794
# 2          9327
# 3         17668
# 4         24838
#           ...
# 323700     7131
# 323701    25890
# 323702     7010
# 323703     3142
# 323704    18670
# Name: product_list, Length: 323705, dtype: int64

# %%
# products_list in the orders_df and products_id in the products_df have same values, so renaming
orders_df.rename(columns= {'product_list': 'product_id'}, inplace=True)
orders_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2       33120                  1          5                  9
# 1         2       17794                  2          5                  9
# 2         2        9327                  4          5                  9
# 3         3       17668                  1          5                 17
# 4         3       24838                  2          5                 17
#
#    length
# 0       3
# 1       3
# 2       3
# 3       5
# 4       5

# %%
# Merge the dataframes based on the common column "product_id"
merged_df = pd.merge(orders_df, products_df, on='product_id', how='left')

# %%
# Create the "label" column
merged_df['label'] = 0

# %%
merged_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2       33120                  1          5                  9
# 1         2       17794                  2          5                  9
# 2         2        9327                  4          5                  9
# 3         3       17668                  1          5                 17
# 4         3       24838                  2          5                 17
#
#    length                                     product_name  aisle_id  \
# 0       3                               Organic Egg Whites        86
# 1       3                                          Carrots        83
# 2       3                                    Garlic Powder       104
# 3       5  Unsweetened Chocolate Almond Breeze Almond Milk        91
# 4       5                           Unsweetened Almondmilk        91
#
#    department_id              aisle  department  label
# 0             16               eggs  dairy eggs      0
# 1              4   fresh vegetables     produce      0
# 2             13  spices seasonings      pantry      0
# 3             16    soy lactosefree  dairy eggs      0
# 4             16    soy lactosefree  dairy eggs      0

# %%
df1 = merged_df[['product_id', 'order_dow', 'order_hour_of_day', 'product_name', 'aisle_id', 'department_id']].copy()
df1
# Out:
#         product_id  order_dow  order_hour_of_day  \
# 0            33120          5                  9
# 1            17794          5                  9
# 2             9327          5                  9
# 3            17668          5                 17
# 4            24838          5                 17
# ...            ...        ...                ...
# 323700        7131          4                 16
# 323701       25890          0                 13
# 323702        7010          0                 13
# 323703        3142          0                 13
# 323704       18670          0                 13
#
#                                            product_name  aisle_id  \
# 0                                    Organic Egg Whites        86
# 1                                               Carrots        83
# 2                                         Garlic Powder       104
# 3       Unsweetened Chocolate Almond Breeze Almond Milk        91
# 4                                Unsweetened Almondmilk        91
# ...                                                 ...       ...
# 323700                            Light Semisoft Cheese        21
# 323701                Boneless Skinless Chicken Breasts        49
# 323702                       Organic White Basmati Rice        63
# 323703                   Organic Short Grain Brown Rice        63
# 323704                     Original Enriched Rice Drink        91
#
#         department_id
# 0                  16
# 1                   4
# 2                  13
# 3                  16
# 4                  16
# ...               ...
# 323700             16
# 323701             12
# 323702              9
# 323703              9
# 323704             16
#
# [323705 rows x 6 columns]

# %%
df1["aisle_id"].max()
# Out:
# 134

# %%
# Assuming your DataFrame is named 'df' and the column containing product IDs is 'product_id'

# Create a dictionary mapping unique product IDs to consecutive integers
unique_ids = {prod_id: i for i, prod_id in enumerate(df1['product_id'].unique())}
unique_aisle = {a_id: j for j, a_id in enumerate(df1['aisle_id'].unique())}

# Add a new column 'unique_product_id' to the DataFrame with the assigned unique IDs
df1['unique_product_id'] = df1['product_id'].map(unique_ids)+1
df1['unique_aisle_id'] = df1['aisle_id'].map(unique_aisle)+1

# Verify the updated DataFrame
df1
# Out:
#         product_id  order_dow  order_hour_of_day  \
# 0            33120          5                  9
# 1            17794          5                  9
# 2             9327          5                  9
# 3            17668          5                 17
# 4            24838          5                 17
# ...            ...        ...                ...
# 323700        7131          4                 16
# 323701       25890          0                 13
# 323702        7010          0                 13
# 323703        3142          0                 13
# 323704       18670          0                 13
#
#                                            product_name  aisle_id  \
# 0                                    Organic Egg Whites        86
# 1                                               Carrots        83
# 2                                         Garlic Powder       104
# 3       Unsweetened Chocolate Almond Breeze Almond Milk        91
# 4                                Unsweetened Almondmilk        91
# ...                                                 ...       ...
# 323700                            Light Semisoft Cheese        21
# 323701                Boneless Skinless Chicken Breasts        49
# 323702                       Organic White Basmati Rice        63
# 323703                   Organic Short Grain Brown Rice        63
# 323704                     Original Enriched Rice Drink        91
#
#         department_id  unique_product_id  unique_aisle_id
# 0                  16                  1                1
# 1                   4                  2                2
# 2                  13                  3                3
# 3                  16                  4                4
# 4                  16                  5                4
# ...               ...                ...              ...
# 323700             16                934               36
# 323701             12                 68               38
# 323702              9                316               41
# 323703              9                464               41
# 323704             16                329                4
#
# [323705 rows x 8 columns]

# %%
df2 = df1[['unique_product_id', 'order_dow', 'order_hour_of_day', 'unique_aisle_id', 'department_id','product_name']].copy()
df2
# Out:
#         unique_product_id  order_dow  order_hour_of_day  unique_aisle_id  \
# 0                       1          5                  9                1
# 1                       2          5                  9                2
# 2                       3          5                  9                3
# 3                       4          5                 17                4
# 4                       5          5                 17                4
# ...                   ...        ...                ...              ...
# 323700                934          4                 16               36
# 323701                 68          0                 13               38
# 323702                316          0                 13               41
# 323703                464          0                 13               41
# 323704                329          0                 13                4
#
#         department_id                                     product_name
# 0                  16                               Organic Egg Whites
# 1                   4                                          Carrots
# 2                  13                                    Garlic Powder
# 3                  16  Unsweetened Chocolate Almond Breeze Almond Milk
# 4                  16                           Unsweetened Almondmilk
# ...               ...                                              ...
# 323700             16                            Light Semisoft Cheese
# 323701             12                Boneless Skinless Chicken Breasts
# 323702              9                       Organic White Basmati Rice
# 323703              9                   Organic Short Grain Brown Rice
# 323704             16                     Original Enriched Rice Drink
#
# [323705 rows x 6 columns]

# %%
df2.rename(columns= {'unique_product_id': 'product_id'}, inplace=True)
df2.head()
# Out:
#    product_id  order_dow  order_hour_of_day  unique_aisle_id  department_id  \
# 0           1          5                  9                1             16
# 1           2          5                  9                2              4
# 2           3          5                  9                3             13
# 3           4          5                 17                4             16
# 4           5          5                 17                4             16
#
#                                       product_name
# 0                               Organic Egg Whites
# 1                                          Carrots
# 2                                    Garlic Powder
# 3  Unsweetened Chocolate Almond Breeze Almond Milk
# 4                           Unsweetened Almondmilk

# %%
df2.rename(columns= {'unique_aisle_id': 'aisle_id'}, inplace=True)
df2.head()
# Out:
#    product_id  order_dow  order_hour_of_day  aisle_id  department_id  \
# 0           1          5                  9         1             16
# 1           2          5                  9         2              4
# 2           3          5                  9         3             13
# 3           4          5                 17         4             16
# 4           5          5                 17         4             16
#
#                                       product_name
# 0                               Organic Egg Whites
# 1                                          Carrots
# 2                                    Garlic Powder
# 3  Unsweetened Chocolate Almond Breeze Almond Milk
# 4                           Unsweetened Almondmilk

# %%
# Creating a dictionary where product_id is key and aisle_id and department_id is values.
dictionary = {}

for index, row in df2.iterrows():
    key = row['product_id']
    value1 = row['aisle_id']
    value2 = row['department_id']
    dictionary[key] = [value1, value2]

print(dictionary)
# Out:
# {1: [1, 16], 2: [2, 4], 3: [3, 13], 4: [4, 16], 5: [4, 16], 6: [5, 4], 7: [2, 4], 8: [5, 4], 9: [6, 17], 10: [2, 4], 11: [7, 1], 12: [8, 7], 13: [9, 14], 14: [5, 4], 15: [2, 4], 16: [10, 4], 17: [2, 4], 18: [11, 4], 19: [12, 19], 20: [13, 15], 21: [14, 1], 22: [15, 13], 23: [16, 16], 24: [17, 7], 25: [12, 19], 26: [18, 7], 27: [8, 7], 28: [18, 7], 29: [19, 7], 30: [20, 1], 31: [21, 14], 32: [7, 1], 33: [22, 16], 34: [23, 7], 35: [13, 15], 36: [15, 13], 37: [19, 7], 38: [19, 7], 39: [24, 19], 40: [2, 4], 41: [7, 1], 42: [25, 16], 43: [26, 13], 44: [27, 18], 45: [5, 4], 46: [2, 4], 47: [28, 19], 48: [11, 4], 49: [29, 7], 50: [11, 4], 51: [11, 4], 52: [23, 7], 53: [2, 4], 54: [30, 3], 55: [31, 20], 56: [22, 16], 57: [11, 4], 58: [32, 16], 59: [33, 9], 60: [2, 4], 61: [5, 4], 62: [34, 1], 63: [34, 1], 64: [35, 12], 65: [36, 16], 66: [37, 1], 67: [7, 1], 68: [38, 12], 69: [4, 16], 70: [39, 17], 71: [5, 4], 72: [7, 1], 73: [11, 4], 74: [22, 16], 75: [16, 16], 76: [25, 16], 77: [26, 13], 78: [22, 16], 79: [2, 4], 80: [19, 7], 81: [11, 4], 82: [40, 4], 83: [40, 4], 84: [4, 16], 85: [7, 1], 86: [8, 7], 87: [41, 9], 88: [42, 19], 89: [2, 4], 90: [4, 16], 91: [5, 4], 92: [7, 1], 93: [5, 4], 94: [14, 1], 95: [23, 7], 96: [36, 16], 97: [12, 19], 98: [17, 7], 99: [2, 4], 100: [12, 19], 101: [43, 19], 102: [2, 4], 103: [11, 4], 104: [2, 4], 105: [14, 1], 106: [22, 16], 107: [25, 16], 108: [4, 16], 109: [20, 1], 110: [14, 1], 111: [31, 20], 112: [6, 17], 113: [11, 4], 114: [5, 4], 115: [35, 12], 116: [11, 4], 117: [44, 16], 118: [22, 16], 119: [45, 1], 120: [46, 15], 121: [11, 4], 122: [4, 16], 123: [10, 4], 124: [47, 13], 125: [44, 16], 126: [36, 16], 127: [34, 1], 128: [2, 4], 129: [22, 16], 130: [19, 7], 131: [11, 4], 132: [2, 4], 133: [15, 13], 134: [5, 4], 135: [30, 3], 136: [11, 4], 137: [11, 4], 138: [48, 3], 139: [1, 16], 140: [12, 19], 141: [11, 4], 142: [49, 13], 143: [2, 4], 144: [11, 4], 145: [11, 4], 146: [50, 20], 147: [11, 4], 148: [11, 4], 149: [51, 9], 150: [22, 16], 151: [11, 4], 152: [36, 16], 153: [4, 16], 154: [40, 4], 155: [16, 16], 156: [11, 4], 157: [22, 16], 158: [52, 12], 159: [4, 16], 160: [11, 4], 161: [5, 4], 162: [13, 15], 163: [2, 4], 164: [7, 1], 165: [19, 7], 166: [22, 16], 167: [6, 17], 168: [53, 6], 169: [22, 16], 170: [22, 16], 171: [51, 9], 172: [12, 19], 173: [31, 20], 174: [8, 7], 175: [12, 19], 176: [34, 1], 177: [19, 7], 178: [11, 4], 179: [11, 4], 180: [27, 18], 181: [5, 4], 182: [44, 16], 183: [41, 9], 184: [54, 12], 185: [2, 4], 186: [55, 15], 187: [8, 7], 188: [22, 16], 189: [12, 19], 190: [46, 15], 191: [56, 13], 192: [2, 4], 193: [31, 20], 194: [35, 12], 195: [57, 1], 196: [2, 4], 197: [11, 4], 198: [2, 4], 199: [4, 16], 200: [51, 9], 201: [19, 7], 202: [36, 16], 203: [50, 20], 204: [58, 19], 205: [22, 16], 206: [59, 2], 207: [22, 16], 208: [60, 19], 209: [44, 16], 210: [2, 4], 211: [5, 4], 212: [35, 12], 213: [55, 15], 214: [11, 4], 215: [58, 19], 216: [14, 1], 217: [8, 7], 218: [10, 4], 219: [22, 16], 220: [10, 4], 221: [6, 17], 222: [40, 4], 223: [61, 17], 224: [62, 17], 225: [63, 3], 226: [2, 4], 227: [64, 12], 228: [11, 4], 229: [55, 15], 230: [49, 13], 231: [55, 15], 232: [55, 15], 233: [2, 4], 234: [2, 4], 235: [47, 13], 236: [12, 19], 237: [5, 4], 238: [35, 12], 239: [65, 6], 240: [17, 7], 241: [53, 6], 242: [42, 19], 243: [7, 1], 244: [19, 7], 245: [31, 20], 246: [20, 1], 247: [64, 12], 248: [44, 16], 249: [23, 7], 250: [9, 14], 251: [8, 7], 252: [32, 16], 253: [44, 16], 254: [5, 4], 255: [33, 9], 256: [2, 4], 257: [5, 4], 258: [58, 19], 259: [2, 4], 260: [23, 7], 261: [23, 7], 262: [23, 7], 263: [31, 20], 264: [44, 16], 265: [5, 4], 266: [1, 16], 267: [66, 15], 268: [19, 7], 269: [67, 19], 270: [2, 4], 271: [49, 13], 272: [60, 19], 273: [2, 4], 274: [26, 13], 275: [56, 13], 276: [22, 16], 277: [6, 17], 278: [46, 15], 279: [2, 4], 280: [68, 7], 281: [54, 12], 282: [2, 4], 283: [47, 13], 284: [4, 16], 285: [69, 20], 286: [36, 16], 287: [16, 16], 288: [1, 16], 289: [42, 19], 290: [1, 16],  ...

# %%
# Save the dictionary as a pickle file
with open('dictionary.pkl', 'wb') as file:
    pickle.dump(dictionary, file)

print(f"Dictionary saved as 'dictionary.pkl'.")
# Out:
# Dictionary saved as 'dictionary.pkl'.

# %%
# Creating a dictionary where product_id is key and product_name is the value.
dictionary2 = {}

for index, row in df2.iterrows():
    key = row['product_id']
    value = row['product_name']
    dictionary2[key] = [value]

print(dictionary2)

# Save the dictionary as a pickle file
with open('prod_dict.pkl', 'wb') as file1:
    pickle.dump(dictionary2, file1)

print(f"Product dictionary saved as 'prod_dict.pkl'.")
# Out:
# {1: ['Organic Egg Whites'], 2: ['Carrots'], 3: ['Garlic Powder'], 4: ['Unsweetened Chocolate Almond Breeze Almond Milk'], 5: ['Unsweetened Almondmilk'], 6: ['Lemons'], 7: ['Organic Ginger Root'], 8: ['Organic Baby Spinach'], 9: ['One Ply Choose A Size Big Roll Paper Towel Rolls'], 10: ['Artichokes'], 11: ['Pineapple Chunks'], 12: ['Orange Juice'], 13: ['Fruit & Nutty Almonds Raisins Cranberries Pecans Granola'], 14: ['Baby Spinach'], 15: ['Green Beans'], 16: ['Organic Cilantro'], 17: ['Organic Butterhead (Boston, Butter, Bibb) Lettuce'], 18: ['Organic Strawberries'], 19: ['Tortilla Strips Restaurant Style'], 20: ['Traditional Refried Beans'], 21: ['Teriyaki & Pineapple Chicken Meatballs'], 22: ['Extra Virgin Olive Oil'], 23: ['French Vanilla Coffee Creamer'], 24: ['Ruby Red Grapefruit Juice'], 25: ['Original Potato Chips'], 26: ['Soda'], 27: ['Lemonade'], 28: ['Diet Tonic Water'], 29: ['Sparkling Natural Mineral Water'], 30: ['Organic Mini Homestyle Waffles'], 31: ['Organic Mesa Sunrise Cereal'], 32: ['Organic Broccoli Florets'], 33: ['Organic Whole Milk'], 34: ['Hair Bender Whole Bean Coffee'], 35: ['Pinto Beans No Salt Added'], 36: ['Organic Extra Virgin Olive Oil'], 37: ['Spring Water'], 38: ['Water'], 39: ['Original Popcorn'], 40: ['Asparagus'], 41: ['Frozen Broccoli Florets'], 42: ['Organic Unsalted Butter'], 43: ['Organic Hazelnut Spread'], 44: ['Organic Fiber & Protein Pear Blueberry & Spinach Baby Food'], 45: ['Organic Baby Carrots'], 46: ['Organic Whole White Mushrooms'], 47: ['Nilla Wafers'], 48: ['Red Delicious Apple'], 49: ['Fruit Punch Sports Drink'], 50: ['Banana'], 51: ['Frozen Organic Blueberries'], 52: ['Cold Brew Coffee'], 53: ['Iceberg Lettuce'], 54: ['Butter Top White Bread'], 55: ['Deli Fresh Honey Smoked Turkey Breast, 98% Fat Free, Gluten Free'], 56: ['2% Reduced Fat Milk'], 57: ['Lime'], 58: ['Dairy-Free Chive Cream Cheese'], 59: ['Gluten-Free Supergrain Pasta Organic Corn & Quinoa Blend Penne'], 60: ['Organic Red Onion'], 61: ['Organic Baby Spinach Salad'], 62: ['Strawberry Lemonade Frozen Pops'], 63: ['Half Baked® Ice Cream'], 64: ['Smok Cured Turkey Bacon'], 65: ['Natural Muenster Cheese'], 66: ['Shredded Hash Browns'], 67: ['Berry Medley'], 68: ['Boneless Skinless Chicken Breasts'], 69: ['Organic Unsweetened Almond Milk'], 70: ['Parchment Paper'], 71: ['3 lb Clementines'], 72: ['Organic Mango Chunks'], 73: ['Organic Avocado'], 74: ['Whole Organic Omega 3 Milk'], 75: ['Organic Heavy Whipping Cream'], 76: ['Salted Butter'], 77: ['Organic Strawberry Fruit Spread'], 78: ['Cultured Low Fat Buttermilk'], 79: ['Sinfully Sweet Campari Tomatoes'], 80: ['Smartwater'], 81: ['Bag of Organic Bananas'], 82: ['Raspberries'], 83: ['Baby Cucumbers'], 84: ['Organic Unsweetened Soy Milk Beverage'], 85: ['Mango Chunks'], 86: ['Synergy Organic Kombucha Gingerberry'], 87: ['Organic Whole Grain Sprouted Quinoa'], 88: ['Roasted & Salted Almonds'], 89: ['Heirloom Tomato'], 90: ['Organic Lactose Free 1% Lowfat Milk'], 91: ['Clementines, Bag'], 92: ['Organic Mixed Vegetables'], 93: ['Seedless Red Grapes'], 94: ['Gluten Free Mushroom Risotto Bowl'], 95: ['Cold-Brew Black Coffee'], 96: ['Baby Swiss Slices Cheese'], 97: ['Sea Salt Brown Rice Crackers'], 98: ['Coconut Water'], 99: ['Bunny-Luv Organic Carrots'], 100: ['Organic Tortilla Chips'], 101: ['Wint-O-Green'], 102: ['Organic Garnet Sweet Potato (Yam)'], 103: ['Organic Fuji Apple'], 104: ['Yellow Onions'], 105: ['Macaroni & Cheese'], 106: ['Organic 1% Low Fat Milk'], 107: ['Pure Irish Butter'], 108: ['Unsweetened Vanilla Almond Breeze'], 109: ['Eggo Nutri-Grain Blueberry Waffles'], 110: ['Chicken Pot Pie'], 111: ['Deli Select Ultra Thin Honey Ham'], 112: ['Ultra Soft Bathroom Tissue, Double Rolls'], 113: ['Golden Pineapple'], 114: ['Organic Blueberries'], 115: ['Beef Franks'], 116: ['Strawberries'], 117: ['YoKids Squeezers Organic Low-Fat Yogurt, Strawberry'], 118: ['Milk, Vitamin D'], 119: ['Gluten-Free Chicken Nuggets'], 120: ['Organic Chicken Bone Broth'], 121: ['Bananas' ...
# Product dictionary saved as 'prod_dict.pkl'.

# %%
df2.drop(['product_name'], axis=1, inplace=True)

# %%
# creating positive and negative sampling
import random
from tqdm import tqdm

df_preprocessed = pd.DataFrame()

for i in range(0, 7):
    for j in range(0, 24):
        filtered = df2[(df2['order_dow'] == i) & (df2['order_hour_of_day'] == j)]
        no_s = filtered.shape[0]
        filtered['target'] = 1
        df_preprocessed = pd.concat([df_preprocessed, filtered], ignore_index=True, axis=0)
        # print(filtered)

        filtered_keys =  set(filtered['product_id'])
        # print(len(filtered_keys))
        # print(filtered_keys)

        filtered_dict = {key: value for key, value in dictionary.items() if key not in filtered_keys}
        # print(filtered_dict.keys())
        # print(filtered_dict)


        random_pairs = np.random.choice(list(filtered_dict.keys()), no_s, replace=True)
        # print(random_pairs)
        # random_dict = dict(random_pairs)

        # print(random_dict)

        data = [{'product_id': item,'order_dow': i, 'order_hour_of_day':j ,'aisle_id': dictionary[item][0], 'department_id': dictionary[item][1], 'target':0}
                for item in random_pairs]

        neg_df = pd.DataFrame(data)

        df_preprocessed = pd.concat([df_preprocessed, neg_df], ignore_index=True, axis=0)
# Out:
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_10448\3153799270.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1

# %%
df_preprocessed
# Out:
#         product_id  order_dow  order_hour_of_day  aisle_id  department_id  \
# 0              315          0                  0        20              1
# 1              103          0                  0        11              4
# 2              300          0                  0         5              4
# 3              881          0                  0        30              3
# 4               50          0                  0        11              4
# ...            ...        ...                ...       ...            ...
# 647405        1773          6                 23        58             19
# 647406        1192          6                 23        44             16
# 647407        1435          6                 23        41              9
# 647408        1877          6                 23        17              7
# 647409        1686          6                 23        35             12
#
#         target
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 647405       0
# 647406       0
# 647407       0
# 647408       0
# 647409       0
#
# [647410 rows x 6 columns]

# %%
df_preprocessed['target'].value_counts()
# Out:
# target
# 1    323705
# 0    323705
# Name: count, dtype: int64

# %%
df_preprocessed['product_id'].nunique()
# Out:
# 2965

# %%
df_preprocessed.to_csv('data\Preprocessed_instacart.csv', index=False)

# %% [markdown]
# ## Checking out the most bought things on a saturday at 2 pm to validate the predictions

# %%
# selected_rows = merged_df[(merged_df["order_dow"] == 6) & (merged_df["order_hour_of_day"] == 14)]
# print(selected_rows.head(10))
# Out:
#      order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 307        99       38200                  1          6                 14
# 308        99       35176                  3          6                 14
# 309        99       46584                  5          6                 14
# 729       232        8193                  1          6                 14
# 730       232       17794                  2          6                 14
# 731       232       44293                  3          6                 14
# 732       232       39055                  4          6                 14
# 733       232       21137                  5          6                 14
# 867       278       15269                  1          6                 14
# 868       278        3880                  2          6                 14
#
#      length                                     product_name  aisle_id  \
# 307       3                                      Apple Juice        31
# 308       3                 Cream Cheese Cream Cheese Spread       108
# 309       3     YoKids Blueberry & Strawberry/Vanilla Yogurt       120
# 729       5                                    Russet Potato        83
# 730       5                                          Carrots        83
# 731       5  Organic Frosted Wildberry Acai Toaster Pastries        48
# 732       5                                  Mild Salsa Roja        67
# 733       5                             Organic Strawberries        24
# 867       4                    Natural Medium Cheddar Cheese        21
# 868       4                             Corn Maize Tortillas       128
#
#      department_id                    aisle  department  label
# 307              7             refrigerated   beverages      0
# 308             16     other creams cheeses  dairy eggs      0
# 309             16                   yogurt  dairy eggs      0
# 729              4         fresh vegetables     produce      0
# 730              4         fresh vegetables     produce      0
# 731             14  breakfast bars pastries   breakfast      0
# 732             20     fresh dips tapenades        deli      0
# 733              4             fresh fruits     produce      0
# 867             16          packaged cheese  dairy eggs      0
# 868              3     tortillas flat bread      bakery      0

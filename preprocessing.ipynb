# %%
import numpy as np
import pandas as pd
import pickle

# %%
products_df = pd.read_csv("data\data_processed_gte25\products.csv")
products_df.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0           1                      Chocolate Sandwich Cookies        61
# 1          10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 2          34                            Peanut Butter Cereal       121
# 3          45                               European Cucumber        83
# 4          79                Wild Albacore Tuna No Salt Added        95
#
#    department_id                          aisle    department
# 0             19                  cookies cakes        snacks
# 1              7  water seltzer sparkling water     beverages
# 2             14                         cereal     breakfast
# 3              4               fresh vegetables       produce
# 4             15            canned meat seafood  canned goods

# %%
orders_df = pd.read_csv("data\data_processed_gte25\orders.csv")
orders_df.head()
# Out:
#    order_id  product_list  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2         33120                  1          5                  9
# 1         2         17794                  2          5                  9
# 2         2          9327                  4          5                  9
# 3         3         17668                  1          5                 17
# 4         3         24838                  2          5                 17
#
#    length
# 0       3
# 1       3
# 2       3
# 3       5
# 4       5

# %%
print("Shape of orders dataframe: ", orders_df.shape)
print("Shape of productss dataframe: ", products_df.shape)
# Out:
# Shape of orders dataframe:  (323705, 6)
# Shape of productss dataframe:  (2965, 6)

# %%
products_df["product_id"]
# Out:
# 0           1
# 1          10
# 2          34
# 3          45
# 4          79
#         ...
# 2960    49605
# 2961    49610
# 2962    49621
# 2963    49667
# 2964    49683
# Name: product_id, Length: 2965, dtype: int64

# %%
orders_df["product_list"]
# Out:
# 0         33120
# 1         17794
# 2          9327
# 3         17668
# 4         24838
#           ...
# 323700     7131
# 323701    25890
# 323702     7010
# 323703     3142
# 323704    18670
# Name: product_list, Length: 323705, dtype: int64

# %%
# products_list in the orders_df and products_id in the products_df have same values, so renaming
orders_df.rename(columns= {'product_list': 'product_id'}, inplace=True)
orders_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2       33120                  1          5                  9
# 1         2       17794                  2          5                  9
# 2         2        9327                  4          5                  9
# 3         3       17668                  1          5                 17
# 4         3       24838                  2          5                 17
#
#    length
# 0       3
# 1       3
# 2       3
# 3       5
# 4       5

# %%
# Merge the dataframes based on the common column "product_id"
merged_df = pd.merge(orders_df, products_df, on='product_id', how='left')

# %%
merged_df
# Out:
#         order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0              2       33120                  1          5                  9
# 1              2       17794                  2          5                  9
# 2              2        9327                  4          5                  9
# 3              3       17668                  1          5                 17
# 4              3       24838                  2          5                 17
# ...          ...         ...                ...        ...                ...
# 323700    105628        7131                  5          4                 16
# 323701    105629       25890                  1          0                 13
# 323702    105629        7010                  2          0                 13
# 323703    105629        3142                  3          0                 13
# 323704    105629       18670                  5          0                 13
#
#         length                                     product_name  aisle_id  \
# 0            3                               Organic Egg Whites        86
# 1            3                                          Carrots        83
# 2            3                                    Garlic Powder       104
# 3            5  Unsweetened Chocolate Almond Breeze Almond Milk        91
# 4            5                           Unsweetened Almondmilk        91
# ...        ...                                              ...       ...
# 323700       5                            Light Semisoft Cheese        21
# 323701       4                Boneless Skinless Chicken Breasts        49
# 323702       4                       Organic White Basmati Rice        63
# 323703       4                   Organic Short Grain Brown Rice        63
# 323704       4                     Original Enriched Rice Drink        91
#
#         department_id                    aisle       department
# 0                  16                     eggs       dairy eggs
# 1                   4         fresh vegetables          produce
# 2                  13        spices seasonings           pantry
# 3                  16          soy lactosefree       dairy eggs
# 4                  16          soy lactosefree       dairy eggs
# ...               ...                      ...              ...
# 323700             16          packaged cheese       dairy eggs
# 323701             12         packaged poultry     meat seafood
# 323702              9  grains rice dried goods  dry goods pasta
# 323703              9  grains rice dried goods  dry goods pasta
# 323704             16          soy lactosefree       dairy eggs
#
# [323705 rows x 11 columns]

# %%
# Create the "label" column
merged_df['label'] = 0

# %%
merged_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  order_dow  order_hour_of_day  \
# 0         2       33120                  1          5                  9
# 1         2       17794                  2          5                  9
# 2         2        9327                  4          5                  9
# 3         3       17668                  1          5                 17
# 4         3       24838                  2          5                 17
#
#    length                                     product_name  aisle_id  \
# 0       3                               Organic Egg Whites        86
# 1       3                                          Carrots        83
# 2       3                                    Garlic Powder       104
# 3       5  Unsweetened Chocolate Almond Breeze Almond Milk        91
# 4       5                           Unsweetened Almondmilk        91
#
#    department_id              aisle  department  label
# 0             16               eggs  dairy eggs      0
# 1              4   fresh vegetables     produce      0
# 2             13  spices seasonings      pantry      0
# 3             16    soy lactosefree  dairy eggs      0
# 4             16    soy lactosefree  dairy eggs      0

# %%
df1 = merged_df[['product_id', 'order_dow', 'order_hour_of_day', 'aisle_id', 'department_id']].copy()
df1
# Out:
#         product_id  order_dow  order_hour_of_day  aisle_id  department_id
# 0            33120          5                  9        86             16
# 1            17794          5                  9        83              4
# 2             9327          5                  9       104             13
# 3            17668          5                 17        91             16
# 4            24838          5                 17        91             16
# ...            ...        ...                ...       ...            ...
# 323700        7131          4                 16        21             16
# 323701       25890          0                 13        49             12
# 323702        7010          0                 13        63              9
# 323703        3142          0                 13        63              9
# 323704       18670          0                 13        91             16
#
# [323705 rows x 5 columns]

# %%
# Assuming your DataFrame is named 'df' and the column containing product IDs is 'product_id'

# Create a dictionary mapping unique product IDs to consecutive integers
unique_ids = {prod_id: i for i, prod_id in enumerate(df1['product_id'].unique())}

# Add a new column 'unique_product_id' to the DataFrame with the assigned unique IDs
df1['unique_product_id'] = df1['product_id'].map(unique_ids)+1

# Verify the updated DataFrame
df1
# Out:
#         product_id  order_dow  order_hour_of_day  aisle_id  department_id  \
# 0            33120          5                  9        86             16
# 1            17794          5                  9        83              4
# 2             9327          5                  9       104             13
# 3            17668          5                 17        91             16
# 4            24838          5                 17        91             16
# ...            ...        ...                ...       ...            ...
# 323700        7131          4                 16        21             16
# 323701       25890          0                 13        49             12
# 323702        7010          0                 13        63              9
# 323703        3142          0                 13        63              9
# 323704       18670          0                 13        91             16
#
#         unique_product_id
# 0                       1
# 1                       2
# 2                       3
# 3                       4
# 4                       5
# ...                   ...
# 323700                934
# 323701                 68
# 323702                316
# 323703                464
# 323704                329
#
# [323705 rows x 6 columns]

# %%
df2 = df1[['unique_product_id', 'order_dow', 'order_hour_of_day', 'aisle_id', 'department_id']].copy()
df2
# Out:
#         unique_product_id  order_dow  order_hour_of_day  aisle_id  \
# 0                       1          5                  9        86
# 1                       2          5                  9        83
# 2                       3          5                  9       104
# 3                       4          5                 17        91
# 4                       5          5                 17        91
# ...                   ...        ...                ...       ...
# 323700                934          4                 16        21
# 323701                 68          0                 13        49
# 323702                316          0                 13        63
# 323703                464          0                 13        63
# 323704                329          0                 13        91
#
#         department_id
# 0                  16
# 1                   4
# 2                  13
# 3                  16
# 4                  16
# ...               ...
# 323700             16
# 323701             12
# 323702              9
# 323703              9
# 323704             16
#
# [323705 rows x 5 columns]

# %%
df2.rename(columns= {'unique_product_id': 'product_id'}, inplace=True)
df2.head()
# Out:
#    product_id  order_dow  order_hour_of_day  aisle_id  department_id
# 0           1          5                  9        86             16
# 1           2          5                  9        83              4
# 2           3          5                  9       104             13
# 3           4          5                 17        91             16
# 4           5          5                 17        91             16

# %%
# Creating a dictionary where product_id is key and aisle_id and department_id is values.
dictionary = {}

for index, row in df2.iterrows():
    key = row['product_id']
    value1 = row['aisle_id']
    value2 = row['department_id']
    dictionary[key] = [value1, value2]

print(dictionary)
# Out:
# {1: [86, 16], 2: [83, 4], 3: [104, 13], 4: [91, 16], 5: [91, 16], 6: [123, 4], 7: [83, 4], 8: [123, 4], 9: [54, 17], 10: [83, 4], 11: [116, 1], 12: [31, 7], 13: [57, 14], 14: [123, 4], 15: [83, 4], 16: [16, 4], 17: [83, 4], 18: [24, 4], 19: [107, 19], 20: [59, 15], 21: [38, 1], 22: [19, 13], 23: [53, 16], 24: [98, 7], 25: [107, 19], 26: [77, 7], 27: [31, 7], 28: [77, 7], 29: [115, 7], 30: [52, 1], 31: [121, 14], 32: [116, 1], 33: [84, 16], 34: [26, 7], 35: [59, 15], 36: [19, 13], 37: [115, 7], 38: [115, 7], 39: [23, 19], 40: [83, 4], 41: [116, 1], 42: [36, 16], 43: [88, 13], 44: [92, 18], 45: [123, 4], 46: [83, 4], 47: [61, 19], 48: [24, 4], 49: [64, 7], 50: [24, 4], 51: [24, 4], 52: [26, 7], 53: [83, 4], 54: [112, 3], 55: [96, 20], 56: [84, 16], 57: [24, 4], 58: [108, 16], 59: [131, 9], 60: [83, 4], 61: [123, 4], 62: [37, 1], 63: [37, 1], 64: [106, 12], 65: [21, 16], 66: [129, 1], 67: [116, 1], 68: [49, 12], 69: [91, 16], 70: [85, 17], 71: [123, 4], 72: [116, 1], 73: [24, 4], 74: [84, 16], 75: [53, 16], 76: [36, 16], 77: [88, 13], 78: [84, 16], 79: [83, 4], 80: [115, 7], 81: [24, 4], 82: [32, 4], 83: [32, 4], 84: [91, 16], 85: [116, 1], 86: [31, 7], 87: [63, 9], 88: [117, 19], 89: [83, 4], 90: [91, 16], 91: [123, 4], 92: [116, 1], 93: [123, 4], 94: [38, 1], 95: [26, 7], 96: [21, 16], 97: [107, 19], 98: [98, 7], 99: [83, 4], 100: [107, 19], 101: [46, 19], 102: [83, 4], 103: [24, 4], 104: [83, 4], 105: [38, 1], 106: [84, 16], 107: [36, 16], 108: [91, 16], 109: [52, 1], 110: [38, 1], 111: [96, 20], 112: [54, 17], 113: [24, 4], 114: [123, 4], 115: [106, 12], 116: [24, 4], 117: [120, 16], 118: [84, 16], 119: [34, 1], 120: [69, 15], 121: [24, 4], 122: [91, 16], 123: [16, 4], 124: [17, 13], 125: [120, 16], 126: [21, 16], 127: [37, 1], 128: [83, 4], 129: [84, 16], 130: [115, 7], 131: [24, 4], 132: [83, 4], 133: [19, 13], 134: [123, 4], 135: [112, 3], 136: [24, 4], 137: [24, 4], 138: [128, 3], 139: [86, 16], 140: [107, 19], 141: [24, 4], 142: [105, 13], 143: [83, 4], 144: [24, 4], 145: [24, 4], 146: [67, 20], 147: [24, 4], 148: [24, 4], 149: [9, 9], 150: [84, 16], 151: [24, 4], 152: [21, 16], 153: [91, 16], 154: [32, 4], 155: [53, 16], 156: [24, 4], 157: [84, 16], 158: [39, 12], 159: [91, 16], 160: [24, 4], 161: [123, 4], 162: [59, 15], 163: [83, 4], 164: [116, 1], 165: [115, 7], 166: [84, 16], 167: [54, 17], 168: [66, 6], 169: [84, 16], 170: [84, 16], 171: [9, 9], 172: [107, 19], 173: [96, 20], 174: [31, 7], 175: [107, 19], 176: [37, 1], 177: [115, 7], 178: [24, 4], 179: [24, 4], 180: [92, 18], 181: [123, 4], 182: [120, 16], 183: [63, 9], 184: [35, 12], 185: [83, 4], 186: [81, 15], 187: [31, 7], 188: [84, 16], 189: [107, 19], 190: [69, 15], 191: [72, 13], 192: [83, 4], 193: [96, 20], 194: [106, 12], 195: [79, 1], 196: [83, 4], 197: [24, 4], 198: [83, 4], 199: [91, 16], 200: [9, 9], 201: [115, 7], 202: [21, 16], 203: [67, 20], 204: [78, 19], 205: [84, 16], 206: [6, 2], 207: [84, 16], 208: [3, 19], 209: [120, 16], 210: [83, 4], 211: [123, 4], 212: [106, 12], 213: [81, 15], 214: [24, 4], 215: [78, 19], 216: [38, 1], 217: [31, 7], 218: [16, 4], 219: [84, 16], 220: [16, 4], 221: [54, 17], 222: [32, 4], 223: [114, 17], 224: [74, 17], 225: [93, 3], 226: [83, 4], 227: [15, 12], 228: [24, 4], 229: [81, 15], 230: [105, 13], 231: [81, 15], 232: [81, 15], 233: [83, 4], 234: [83, 4], 235: [17, 13], 236: [107, 19], 237: [123, 4], 238: [106, 12], 239: [30, 6], 240: [98, 7], 241: [66, 6], 242: [117, 19], 243: [116, 1], 244: [115, 7], 245: [96, 20], 246: [52, 1], 247: [15, 12], 248: [120, 16], 249: [26, 7], 250: [57, 14], 251: [31, 7], 252: [108, 16], 253: [120, 16], 254: [123, 4], 255: [131, 9], 256: [83, 4], 257: [123, 4], 258: [78, 19], 259: [83, 4], 260: [26, 7], 261: [26, 7], 262: [26, 7], 263: [96, 20], 264: [120, 16], 265: [123, 4], 266: [86, 16], 267: [99, 15], 268: [115, 7], 269: [50, 19], 270: [83, 4], 271: [105, 13], 272: [3, 19], 273: [83, 4], 274: [88, 13], 275: [72, 13], 276: [84, 16], 277: [54, 17], 278: [69, 15], 279: [83, 4], 280: [9 ...
# 2965

# %%
# Save the dictionary as a pickle file
with open('dictionary.pkl', 'wb') as file:
    pickle.dump(dictionary, file)

print(f"Dictionary saved as 'dictionary.pkl'.")
# Out:
# Dictionary saved as 'dictionary.pkl'.

# %%
# creating positive and negative sampling
import random
from tqdm import tqdm

df_preprocessed = pd.DataFrame()

for i in range(0, 7):
    for j in range(0, 24):
        filtered = df2[(df2['order_dow'] == i) & (df2['order_hour_of_day'] == j)]
        no_s = filtered.shape[0]
        filtered['target'] = 1
        df_preprocessed = pd.concat([df_preprocessed, filtered], ignore_index=True, axis=0)
        # print(filtered)

        filtered_keys =  set(filtered['product_id'])
        # print(len(filtered_keys))
        # print(filtered_keys)

        filtered_dict = {key: value for key, value in dictionary.items() if key not in filtered_keys}
        # print(filtered_dict.keys())
        # print(filtered_dict)


        random_pairs = np.random.choice(list(filtered_dict.keys()), no_s, replace=True)
        # print(random_pairs)
        # random_dict = dict(random_pairs)

        # print(random_dict)

        data = [{'product_id': item,'order_dow': i, 'order_hour_of_day':j ,'aisle_id': dictionary[item][0], 'department_id': dictionary[item][1], 'target':0}
                for item in random_pairs]

        neg_df = pd.DataFrame(data)

        df_preprocessed = pd.concat([df_preprocessed, neg_df], ignore_index=True, axis=0)
# Out:
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1
# C:\Users\Image\AppData\Local\Temp\ipykernel_15108\1106648631.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['target'] = 1

# %%
df_preprocessed
# Out:
#         product_id  order_dow  order_hour_of_day  aisle_id  department_id  \
# 0              315          0                  0        52              1
# 1              103          0                  0        24              4
# 2              300          0                  0       123              4
# 3              881          0                  0       112              3
# 4               50          0                  0        24              4
# ...            ...        ...                ...       ...            ...
# 647405         161          6                 23       123              4
# 647406        1273          6                 23         9              9
# 647407        2185          6                 23       107             19
# 647408        2234          6                 23        93              3
# 647409          88          6                 23       117             19
#
#         target
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 647405       0
# 647406       0
# 647407       0
# 647408       0
# 647409       0
#
# [647410 rows x 6 columns]

# %%
df_preprocessed['target'].value_counts()
# Out:
# target
# 1    323705
# 0    323705
# Name: count, dtype: int64

# %%
df_preprocessed['product_id'].nunique()
# Out:
# 2965

# %%
df_preprocessed.to_csv('data\Preprocessed_instacart.csv', index=False)
